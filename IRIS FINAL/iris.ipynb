# %% [markdown]
# # IMPORTING ALL THE ESSENTIAL LIBRARIES

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %% [markdown]
# # LOADING THE DATASET

# %%
columns = ['Sepal length', 'sepal width', 'petal length', 'petal width', 'class_labels']
#load the data
df=pd.read_csv('iris.data', names=columns)

# %% [markdown]
# # VISUALIZATION OF OUR DATASET

# %%
df.describe()
#VISUALIZE THE WHOLE DATASET
# Out:
#        Sepal length  sepal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
sns.pairplot(df, hue='class_labels')

# %% [markdown]
# ## SEPERATING INPUT COLUMNS AND OUTPUT COLUMNS

# %%
#Seperate features and target
data=df.values
X=data[:,0:4]
Y=data[:,4]
print(x)
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.0 1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.0 3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.0 3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.4 3.7 1.5 0.2]
#  [4.8 3.4 1.6 0.2]
#  [4.8 3.0 1.4 0.1]
#  [4.3 3.0 1.1 0.1]
#  [5.8 4.0 1.2 0.2]
#  [5.7 4.4 1.5 0.4]
#  [5.4 3.9 1.3 0.4]
#  [5.1 3.5 1.4 0.3]
#  [5.7 3.8 1.7 0.3]
#  [5.1 3.8 1.5 0.3]
#  [5.4 3.4 1.7 0.2]
#  [5.1 3.7 1.5 0.4]
#  [4.6 3.6 1.0 0.2]
#  [5.1 3.3 1.7 0.5]
#  [4.8 3.4 1.9 0.2]
#  [5.0 3.0 1.6 0.2]
#  [5.0 3.4 1.6 0.4]
#  [5.2 3.5 1.5 0.2]
#  [5.2 3.4 1.4 0.2]
#  [4.7 3.2 1.6 0.2]
#  [4.8 3.1 1.6 0.2]
#  [5.4 3.4 1.5 0.4]
#  [5.2 4.1 1.5 0.1]
#  [5.5 4.2 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.0 3.2 1.2 0.2]
#  [5.5 3.5 1.3 0.2]
#  [4.9 3.1 1.5 0.1]
#  [4.4 3.0 1.3 0.2]
#  [5.1 3.4 1.5 0.2]
#  [5.0 3.5 1.3 0.3]
#  [4.5 2.3 1.3 0.3]
#  [4.4 3.2 1.3 0.2]
#  [5.0 3.5 1.6 0.6]
#  [5.1 3.8 1.9 0.4]
#  [4.8 3.0 1.4 0.3]
#  [5.1 3.8 1.6 0.2]
# ...

# %% [markdown]
# # SPLITING THE DATA INTO TRAINING AND TESTING

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
print(X_train)
# Out:
# [[6.1 2.6 5.6 1.4]
#  [6.1 3.0 4.9 1.8]
#  [5.0 3.0 1.6 0.2]
#  [5.4 3.7 1.5 0.2]
#  [5.5 2.4 3.7 1.0]
#  [6.5 3.0 5.8 2.2]
#  [5.5 2.5 4.0 1.3]
#  [5.4 3.0 4.5 1.5]
#  [4.6 3.2 1.4 0.2]
#  [5.6 3.0 4.1 1.3]
#  [6.5 3.2 5.1 2.0]
#  [5.4 3.9 1.3 0.4]
#  [6.3 3.3 4.7 1.6]
#  [6.2 2.9 4.3 1.3]
#  [7.0 3.2 4.7 1.4]
#  [5.6 2.7 4.2 1.3]
#  [6.7 2.5 5.8 1.8]
#  [5.1 3.8 1.9 0.4]
#  [4.8 3.0 1.4 0.3]
#  [6.9 3.1 5.1 2.3]
#  [6.0 2.2 4.0 1.0]
#  [5.8 2.6 4.0 1.2]
#  [5.9 3.0 4.2 1.5]
#  [6.2 2.8 4.8 1.8]
#  [7.2 3.6 6.1 2.5]
#  [4.3 3.0 1.1 0.1]
#  [6.3 2.5 5.0 1.9]
#  [5.8 2.7 3.9 1.2]
#  [6.7 3.0 5.0 1.7]
#  [5.0 3.4 1.6 0.4]
#  [5.1 3.8 1.5 0.3]
#  [5.1 2.5 3.0 1.1]
#  [4.6 3.1 1.5 0.2]
#  [6.2 2.2 4.5 1.5]
#  [6.9 3.2 5.7 2.3]
#  [6.7 3.1 4.4 1.4]
#  [6.4 2.8 5.6 2.2]
#  [4.6 3.6 1.0 0.2]
#  [5.5 4.2 1.4 0.2]
#  [6.9 3.1 4.9 1.5]
#  [5.4 3.4 1.5 0.4]
#  [6.5 2.8 4.6 1.5]
#  [7.7 2.6 6.9 2.3]
#  [6.7 3.1 4.7 1.5]
#  [5.9 3.0 5.1 1.8]
#  [4.8 3.0 1.4 0.1]
#  [6.4 3.2 5.3 2.3]
# ...

# %% [markdown]
# # MODEL 1: SUPPORT VECTOR MACHINE ALGORITHM

# %%
from sklearn.svm import SVC

model_svc =SVC()
model_svc.fit(X_train, y_train)
# Out:
# SVC()

# %%
prediction1 = model_svc.predict(X_test)
#calculate the accuracy
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, prediction1))
# Out:
# 0.9333333333333333

# %% [markdown]
# # MODEL 2: LOGISTIC REGRESSION

# %%
#Logisitic Regression
from sklearn.linear_model import LogisticRegression
model_LR = LogisticRegression()
model_LR.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
prediction2 = model_LR.predict(X_test)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,prediction2)*100)
# Out:
# 93.33333333333333

# %% [markdown]
# # MODEL 3: DECISION TREE CLASSIFIER

# %%
from sklearn.tree import DecisionTreeClassifier
model_DTC= DecisionTreeClassifier()
model_DTC.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
prediciton3 = model_svc.predict(X_test)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, prediciton3)*100)
# Out:
# 93.33333333333333

# %% [markdown]
# # DETAILED CLASSIFICATION REPORT

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, prediction2))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        13
# Iris-versicolor       1.00      0.71      0.83         7
#  Iris-virginica       0.83      1.00      0.91        10
#
#        accuracy                           0.93        30
#       macro avg       0.94      0.90      0.91        30
#    weighted avg       0.94      0.93      0.93        30

# %% [markdown]
# # PREDICTION OF SPECIES FROM THE MANUALLY GIVEN INPUT

# %%
X_new = np.array([[ 3, 2, 1, 0.2], [4.9, 2.2, 3.8, 1.1], [5.3, 2.5, 4.6, 1.9]])

prediciton = model_svc.predict(X_new)
print("Predicition of Species: {}" .format(prediciton))
# Out:
# Predicition of Species: ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']
